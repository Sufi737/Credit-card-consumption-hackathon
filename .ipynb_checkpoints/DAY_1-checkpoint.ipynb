# %%
import pandas as pd
import numpy as np
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Lasso
from sklearn.linear_model import LinearRegression
from sklearn.feature_selection import SelectFromModel

# %%
df_train=pd.read_csv('Train.csv',delimiter = ',')

# %%
df_train
# Out:
#           ID account_type gender  age  region_code  cc_cons_apr  dc_cons_apr  \
# 0      12554      current      M   35          708    24893.000       378.00
# 1      17645      current      M   35          123    18941.620       966.00
# 2       7604      current      M   55          802     5678.870      2724.00
# 3       1590      current      F   29          867    30489.500      1236.00
# 4      16556      current      M   34          802     7441.400      6906.04
# 5      19106      current      M   27          958     2328.220      1597.54
# 6      10086      current      M   32          805     1643.810      5009.13
# 7       3045      current      M   28          448     5768.500      1963.00
# 8      17368      current      F   67          631      721.000      2405.90
# 9       9756      current      M   37          516    48575.240      4003.80
# 10     14772       saving      M   46          325    66617.000     15049.00
# 11     16901      current      M   38          867     1928.000      3562.00
# 12      9853      current      M   64          805     9304.070     10117.00
# 13       678      current      F   33          723    20743.540      6748.00
# 14     11040      current      M   62          243    18560.260      5431.86
# 15      6147      current      F   28          385     4375.130      1035.00
# 16      1585      current      M   29          860    15465.260      2854.21
# 17     19346      current      F   28          863    23354.880      7177.50
# 18      7262      current      M   66          700    23517.000     10675.26
# 19      1202       saving      M   55          928    21434.000     12764.00
# 20      7791      current      M   60          685    41998.070      3872.00
# 21      5438      current      M   40          685    14644.430     15571.55
# 22     18797      current      M   29          883     6249.520      2031.00
# 23      8661      current      M   63          503    18724.500       177.00
# 24     17362      current      M   30          700     6712.780      6942.00
# 25     10693      current      M   56          606    38460.930      1067.00
# 26      3905      current      M   32          447     1703.090     14604.69
# 27      3334      current      M   62          314     8594.225     16379.52
# 28     17536      current      M   34          950    26025.370      1058.28
# 29      7552      current      M   46          911      732.930      3332.48
# ...      ...          ...    ...  ...          ...          ...          ...
# 14970   7199       saving      M   44          771    12652.000      8345.00
# 14971  16982      current      M   35          488    10162.200       330.78
# 14972  16875      current      M   33          656     3318.500     10671.50
# 14973   1500      current      M   62          883    42222.000       719.01
# 14974   7249       saving      M   53          370     6174.680      3822.00
# 14975  10734      current      M   39          743    66305.000       193.00
# 14976  19837      current      M   34          451    17240.500      4121.43
# 14977   9957      current      M   64          867     8625.475      2306.50
# 14978   2875      current      M   29          658     6175.000       902.00
# 14979  14151      current      M   49          708     7952.290      9748.70
# 14980   5045       saving      M   40          626     8994.620       546.31
# 14981  12637      current      F   37          355    27105.740       933.20
# 14982  11794       saving      M   34          448    66120.540      1174.00
# 14983   3426      current      M   28          858     1891.580       255.00
# 14984   9277       saving      F   38          245     6726.560     13607.00
# 14985   4365       saving      M   58          454     4056.180      1324.60
# 14986  12955      current      M   62          736     3299.720      3552.50
# 14987    458      current      M   33          445    94554.320     12302.59
# 14988   4211       saving      F   37          485     9880.235      1960.31
# 14989  13116      current      M   30          957     3844.500      7684.00
# 14990  13397      current      M  223          801    58692.620    142905.29
# 14991  14189      current      M   30          558     4421.500       481.50
# 14992   2096      current      M   66          640    14181.000     15759.00
# 14993  11967      current      F   49          809    32065.550     10557.00
# 14994   5480      current      M   27          445    30347.750      1390.23
# 14995   6995      current      F   53          653    10443.760      1218.85
# 14996  10376      current      M   44          535    29890.330      6308.00
# 14997   2181      current      M   37          464     4148.980       948.74
# 14998  18417      current      M  220          536   115574.000      7191.05
# 14999   4547      current      M   66          269     7375.670       306.80
#
#        cc_cons_may  dc_cons_may  cc_cons_jun  ...  debit_count_may  \
# 0         10288.00     29664.00    16291.400  ...             40.0
# 1         20672.00       287.00     4217.000  ...             78.0
# 2          1964.50      3933.11    23956.250  ...             82.0
# 3         12609.88      9138.14    17521.000  ...             38.0
# 4          4364.00      1939.00     2121.000  ...             50.0
# 5         19979.75      1045.85    11686.255  ...              2.0
# 6          8921.62      2151.00     6677.955  ...             25.0
# 7         84272.63      1956.00     6794.460  ...             63.0
# 8         28933.37      5672.00    21473.000  ...             81.0
# 9          2112.49      2572.00    15782.520  ...             82.0
# 10        23214.00      3562.00    72910.000  ...             31.0
# 11         3184.14      6815.50    19197.620  ...             12.0
# 12        19837.97      1015.00      860.000  ...             11.0
# 13         1582.48       888.00     2479.500  ...              5.0
# 14        11728.92      3021.00     2321.300  ...            108.0
# 15        14183.42     12489.00    10521.500  ...             12.0
# 16          291.50      3400.00    17374.765  ...              7.0
# 17         3750.43      2277.00    11712.000  ...             14.0
# 18         6612.45      1897.00     4801.000  ...            105.0
# 19         1245.76       188.00     4648.300  ...             50.0
# 20         4447.65       368.00    22165.000  ...             12.0
# 21         4404.27      1032.26    10298.000  ...              6.0
# 22         9147.97      6052.75     9809.545  ...             20.0
# 23         6529.53      3524.57     1685.000  ...             42.0
# 24        10403.80      1670.25    14758.870  ...            171.0
# 25        24747.18      2879.58     1229.000  ...             11.0
# 26         2451.97     11619.80     5488.805  ...              2.0
# 27        35300.38      2841.00     1223.940  ...            108.0
# 28         1131.95       824.67     1430.000  ...             82.0
# 29         3723.70      1624.00     8534.000  ...             16.0
# ...            ...          ...          ...  ...              ...
# 14970      3301.00      3717.00      635.000  ...             63.0
# 14971      9134.42     12112.00     9617.000  ...             25.0
# 14972     13863.23    135662.00     2624.370  ...              5.0
# 14973     12573.87      3037.88     7254.800  ...              6.0
# 14974      9866.14      5393.67     5663.225  ...             13.0
# 14975      4876.00     46817.83    26550.810  ...              8.0
# 14976      4139.50     46531.00      802.000  ...             69.0
# 14977     24385.42      1524.00     9456.000  ...             13.0
# 14978     25761.69     22946.87   100334.510  ...             86.0
# 14979      3089.88      2853.00     7556.300  ...             78.0
# 14980     11022.50      3337.94    48587.135  ...             29.0
# 14981      4717.00      3876.00     9883.960  ...              4.0
# 14982      7895.38      1662.76     8793.000  ...             82.0
# 14983      3001.95       287.00    13459.965  ...             20.0
# 14984      1956.74      2186.14    44141.320  ...             13.0
# 14985     12544.62      5647.00    15238.920  ...             23.0
# 14986    108058.12     20118.00     7893.720  ...             24.0
# 14987      8316.36      6617.78     1093.080  ...            171.0
# 14988     42548.00      2930.00     1689.005  ...             20.0
# 14989      4077.09      3337.94     5848.000  ...             35.0
# 14990      6739.35     11638.00     1252.660  ...             87.0
# 14991      5872.98      1178.00    14479.000  ...              5.0
# 14992     27766.51       498.00    11139.545  ...             11.0
# 14993      3548.68      5995.00    16453.460  ...             27.0
# 14994      2217.46     45480.88    16308.000  ...              1.0
# 14995      7252.24      3873.00     6633.000  ...              8.0
# 14996     16025.50      7610.00     2213.080  ...             20.0
# 14997     19360.26       494.00    44363.910  ...              5.0
# 14998     44341.13     34817.20    20679.000  ...             25.0
# 14999      5859.49      6702.40    33211.650  ...             82.0
#
#        max_credit_amount_may  debit_amount_jun  credit_amount_jun  \
# 0                   24563.00          30051.32           12761.00
# 1                   23948.00          42119.05           76206.00
# 2                   10752.00          58373.25           75283.00
# 3                   12607.00          69851.51           68708.00
# 4                   25213.00          10071.00           80140.00
# 5                   21440.00          52292.68          199925.50
# 6                   20444.00          27354.56          200391.00
# 7                    5473.00          52411.93            7422.00
# 8                   27418.00          59500.90           10425.53
# 9                    1145.00         285604.50           49972.50
# 10                  15636.00          35823.52          153848.00
# 11                  56665.00           1021.00           35132.00
# 12                  17785.00         126930.15           30335.00
# 13                  25578.31          19113.13           92443.00
# 14                  28870.00          20763.12          748139.00
# 15                  19669.00          39971.35             461.79
# 16                  14898.58          58501.21           11867.00
# 17                  47709.00          40627.38          466079.25
# 18                   2555.95          29073.75           26238.00
# 19                  45065.00          85276.00           44530.00
# 20                   2951.00          12439.39           11299.00
# 21                  30325.51         100081.57          202601.38
# 22                 129509.00          36622.40           81066.00
# 23                  31658.00          58012.62           29443.00
# 24                  56643.00          44428.74           12273.75
# 25                 396556.00          34280.06           73905.00
# 26                  25583.00          53790.25          204518.16
# 27                  18548.00          32653.62          951555.00
# 28                 140000.00           7877.33           10184.00
# 29                  11648.00         131557.52             379.00
# ...                      ...               ...                ...
# 14970              122301.00         120102.50          133477.00
# 14971               56458.00         141903.37           99778.40
# 14972               44972.00          27991.36           74372.00
# 14973               62810.00         124928.58           76809.75
# 14974               27034.09          78592.91          102657.50
# 14975              243528.00         152647.12          129577.00
# 14976               22575.00          77549.32           28631.00
# 14977               39459.00         278997.73           50500.00
# 14978               36725.00          52652.63           78866.79
# 14979               33038.00          45851.10           53525.00
# 14980               67367.00          27440.69          157397.50
# 14981               24320.00          68356.73          140120.00
# 14982               53710.00          80855.97           41280.00
# 14983               16000.00          62746.00           51494.00
# 14984              226997.00         558395.50          106766.00
# 14985               20709.00          47650.75           56943.00
# 14986                8470.00          29623.97          235283.02
# 14987               16306.00          49846.26          110703.00
# 14988               21397.00         241358.75           37502.00
# 14989               16187.00            793.00           42396.00
# 14990               69052.00          67065.00           10819.00
# 14991               16187.00          24443.00             358.00
# 14992               31128.00          41973.58           64567.63
# 14993               17454.00          19526.96          114954.00
# 14994               16208.00         297363.00          125022.00
# 14995                6936.00         487751.19           42625.50
# 14996              202639.00           8666.01           34987.55
# 14997               44421.00          97896.48          261432.00
# 14998               22409.00          22693.92           33025.29
# 14999                8084.00          41328.96           78574.00
#
#        credit_count_jun  debit_count_jun  max_credit_amount_jun  loan_enq  \
# 0                   2.0             65.0               50836.00         Y
# 1                  21.0             63.0               23226.00         Y
# 2                   7.0              1.0               27036.00         Y
# 3                  21.0             83.0               43037.00         Y
# 4                   8.0             32.0               32044.00         Y
# 5                   2.0             35.0               17284.00         Y
# 6                  58.0             12.0                6779.00         Y
# 7                   5.0             58.0               56900.00         Y
# 8                   2.0             79.0               12626.00         Y
# 9                   2.0             63.0               18524.00         Y
# 10                 43.0             11.0               21564.00         Y
# 11                 94.0             10.0              171363.00         Y
# 12                  2.0            106.0               63214.00         Y
# 13                 94.0             50.0              155924.00         Y
# 14                  3.0             12.0               24813.00         Y
# 15                  3.0             83.0               10040.39         Y
# 16                 43.0             68.0              388145.00         Y
# 17                 94.0             25.0               20040.00         Y
# 18                  5.0             68.0               65571.50         Y
# 19                 19.0             10.0               30352.00         Y
# 20                 16.0             26.0               48649.00         Y
# 21                 47.0             25.0              241771.00         Y
# 22                 12.0             24.0                5309.00         Y
# 23                  2.0             49.0               15938.00         Y
# 24                  4.0              6.0               62247.00         Y
# 25                 21.0             50.0               13360.00         Y
# 26                 14.0             79.0               15178.00         Y
# 27                  3.0             79.0               41945.00         Y
# 28                  4.0            106.0               29792.00         Y
# 29                  6.0             11.0                5555.00         Y
# ...                 ...              ...                    ...       ...
# 14970               7.0             83.0               28143.00         Y
# 14971               4.0             73.0               62400.00         Y
# 14972               5.0             21.0               22863.00         Y
# 14973               8.0            113.0               20543.00         Y
# 14974              40.0             58.0               30107.00         Y
# 14975               4.0              9.0               25389.00         Y
# 14976              10.0             11.0               25299.00         Y
# 14977               2.0             10.0               73787.00         Y
# 14978              94.0              7.0               30083.00         Y
# 14979              21.0            120.0               20612.00         Y
# 14980              94.0            124.0               73263.00         Y
# 14981               6.0             83.0               35485.00         Y
# 14982               4.0             50.0               26690.00         Y
# 14983               4.0            104.0               17003.00         Y
# 14984               9.0             79.0              157500.00         Y
# 14985               2.0              1.0               43511.00         Y
# 14986               9.0             32.0               88907.00         Y
# 14987              19.0             25.0              168640.00         Y
# 14988               1.0             14.0               20287.00         Y
# 14989              41.0             36.0               13070.00         Y
# 14990               6.0              0.0               13689.00         Y
# 14991               3.0             58.0               11846.40         Y
# 14992              19.0             58.0               25360.00         Y
# 14993               3.0             12.0               23029.00         Y
# 14994              10.0             67.0               11846.40         Y
# 14995              14.0              8.0               82851.00         Y
# 14996              11.0             18.0              118110.47         Y
# 14997               4.0             73.0               49545.00         Y
# 14998               3.0             80.0               16130.00         Y
# 14999              47.0             50.0               22849.00         Y
#
#        emi_active   cc_cons
# 0         1674.09   20014.0
# 1        13043.34   10173.0
# 2        25375.27   16095.0
# 3         3544.33    7707.0
# 4        12780.44   96408.0
# 5         5026.50  130263.0
# 6         1534.93  113479.0
# 7        14689.56    7463.0
# 8         4583.09    5712.0
# 9        16839.22    7647.0
# 10         296.29   15896.0
# 11        2391.74  140730.0
# 12        1029.43  164613.0
# 13        3862.96   18331.0
# 14        3362.62   12329.0
# 15         288.38   10069.0
# 16        1945.12  222566.0
# 17       21718.02   14694.0
# 18        3593.73    3045.0
# 19        1893.46     279.0
# 20         452.76   14040.0
# 21        7734.92    5108.0
# 22        7958.53   19705.0
# 23       12397.88   24455.0
# 24       11084.29   10846.0
# 25       10988.24   17352.0
# 26       12123.58    2774.0
# 27        8445.94    9086.0
# 28       17350.88   13533.0
# 29       38442.24  141413.0
# ...           ...       ...
# 14970    10987.61  177330.0
# 14971    64469.30    2746.0
# 14972    13980.90  335976.0
# 14973     2603.11    8191.0
# 14974     2307.10    7705.0
# 14975      185.53   17158.0
# 14976     7879.04   12419.0
# 14977     1086.69    5405.0
# 14978     4140.41     654.0
# 14979     2578.60   20157.0
# 14980    27113.03   18349.0
# 14981     2909.80    3336.0
# 14982      161.23    4810.0
# 14983     1360.05   10064.0
# 14984       31.30   18610.0
# 14985     1337.65   10537.0
# 14986     1494.18   10303.0
# 14987     2950.65   16049.0
# 14988      530.29    8316.0
# 14989     2646.18   12310.0
# 14990     2200.59   19629.0
# 14991     2896.73    3790.0
# 14992     6284.72   11780.0
# 14993      747.23    6768.0
# 14994     4536.83    1721.0
# 14995    78966.76    4263.0
# 14996     4762.10   11019.0
# 14997     2877.33  404227.0
# 14998    13006.84   28813.0
# 14999     1588.60   16252.0
#
# [15000 rows x 44 columns]

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 44 columns):
# ID                       15000 non-null int64
# account_type             15000 non-null object
# gender                   15000 non-null object
# age                      15000 non-null int64
# region_code              15000 non-null int64
# cc_cons_apr              15000 non-null float64
# dc_cons_apr              15000 non-null float64
# cc_cons_may              15000 non-null float64
# dc_cons_may              15000 non-null float64
# cc_cons_jun              15000 non-null float64
# dc_cons_jun              15000 non-null float64
# cc_count_apr             15000 non-null float64
# cc_count_may             15000 non-null float64
# cc_count_jun             15000 non-null float64
# dc_count_apr             15000 non-null float64
# dc_count_may             15000 non-null float64
# dc_count_jun             15000 non-null float64
# card_lim                 15000 non-null float64
# personal_loan_active     15000 non-null float64
# vehicle_loan_active      15000 non-null float64
# personal_loan_closed     15000 non-null float64
# vehicle_loan_closed      15000 non-null float64
# investment_1             15000 non-null float64
# investment_2             15000 non-null float64
# investment_3             15000 non-null float64
# investment_4             15000 non-null float64
# debit_amount_apr         15000 non-null float64
# credit_amount_apr        15000 non-null float64
# debit_count_apr          15000 non-null float64
# credit_count_apr         15000 non-null float64
# max_credit_amount_apr    15000 non-null float64
# debit_amount_may         15000 non-null float64
# credit_amount_may        15000 non-null float64
# credit_count_may         15000 non-null float64
# debit_count_may          15000 non-null float64
# max_credit_amount_may    15000 non-null float64
# debit_amount_jun         15000 non-null float64
# credit_amount_jun        15000 non-null float64
# credit_count_jun         15000 non-null float64
# debit_count_jun          15000 non-null float64
# max_credit_amount_jun    15000 non-null float64
# loan_enq                 15000 non-null object
# emi_active               15000 non-null float64
# cc_cons                  15000 non-null float64
# dtypes: float64(38), int64(3), object(3)
# memory usage: 5.0+ MB

# %%
(df_train==0).sum()
# Out:
# ID                         0
# account_type               0
# gender                     0
# age                        0
# region_code                0
# cc_cons_apr                0
# dc_cons_apr                0
# cc_cons_may                0
# dc_cons_may                0
# cc_cons_jun                0
# dc_cons_jun                0
# cc_count_apr               0
# cc_count_may               0
# cc_count_jun               0
# dc_count_apr               0
# dc_count_may               0
# dc_count_jun               0
# card_lim                  36
# personal_loan_active       0
# vehicle_loan_active        0
# personal_loan_closed       0
# vehicle_loan_closed        0
# investment_1               0
# investment_2               0
# investment_3               0
# investment_4             960
# debit_amount_apr           0
# credit_amount_apr          0
# debit_count_apr           95
# credit_count_apr         791
# max_credit_amount_apr      0
# debit_amount_may           0
# credit_amount_may          0
# credit_count_may         718
# debit_count_may           60
# max_credit_amount_may      0
# debit_amount_jun           0
# credit_amount_jun          0
# credit_count_jun           0
# debit_count_jun          335
# max_credit_amount_jun      0
# loan_enq                   0
# emi_active                35
# cc_cons                    1
# dtype: int64

# %%
df_train.isna().sum()
# Out:
# ID                       0
# account_type             0
# gender                   0
# age                      0
# region_code              0
# cc_cons_apr              0
# dc_cons_apr              0
# cc_cons_may              0
# dc_cons_may              0
# cc_cons_jun              0
# dc_cons_jun              0
# cc_count_apr             0
# cc_count_may             0
# cc_count_jun             0
# dc_count_apr             0
# dc_count_may             0
# dc_count_jun             0
# card_lim                 0
# personal_loan_active     0
# vehicle_loan_active      0
# personal_loan_closed     0
# vehicle_loan_closed      0
# investment_1             0
# investment_2             0
# investment_3             0
# investment_4             0
# debit_amount_apr         0
# credit_amount_apr        0
# debit_count_apr          0
# credit_count_apr         0
# max_credit_amount_apr    0
# debit_amount_may         0
# credit_amount_may        0
# credit_count_may         0
# debit_count_may          0
# max_credit_amount_may    0
# debit_amount_jun         0
# credit_amount_jun        0
# credit_count_jun         0
# debit_count_jun          0
# max_credit_amount_jun    0
# loan_enq                 0
# emi_active               0
# cc_cons                  0
# dtype: int64

# %%
df1=df_train.loc[:,df_train.dtypes==np.object]

# %%
df2=df_train.loc[:,df_train.dtypes==np.number]
df2
# Out:
#        cc_cons_apr  dc_cons_apr  cc_cons_may  dc_cons_may  cc_cons_jun  \
# 0         24893.00       378.00     10288.00     29664.00     16291.40
# 1         18941.62       966.00     20672.00       287.00      4217.00
# 2          5678.87      2724.00      1964.50      3933.11     23956.25
# 3         30489.50      1236.00     12609.88      9138.14     17521.00
# 4          7441.40      6906.04      4364.00      1939.00      2121.00
# ...            ...          ...          ...          ...          ...
# 14995     10443.76      1218.85      7252.24      3873.00      6633.00
# 14996     29890.33      6308.00     16025.50      7610.00      2213.08
# 14997      4148.98       948.74     19360.26       494.00     44363.91
# 14998    115574.00      7191.05     44341.13     34817.20     20679.00
# 14999      7375.67       306.80      5859.49      6702.40     33211.65
#
#        dc_cons_jun  cc_count_apr  cc_count_may  cc_count_jun  dc_count_apr  \
# 0         11432.00           2.0          26.0          10.0          48.0
# 1           885.00           1.0           7.0          13.0           3.0
# 2          5168.00          43.0          32.0         102.0           4.0
# 3         13650.30          53.0           1.0          50.0           1.0
# 4          6829.18          67.0          47.0          82.0          54.0
# ...            ...           ...           ...           ...           ...
# 14995     10107.00           3.0          36.0           3.0          44.0
# 14996       841.60           1.0          34.0           4.0           7.0
# 14997      1801.77          57.0          23.0          61.0          24.0
# 14998      1010.00           7.0         128.0          44.0           3.0
# 14999       263.00          28.0          71.0          10.0          30.0
#
#        ...  credit_count_may  debit_count_may  max_credit_amount_may  \
# 0      ...               2.0             40.0                24563.0
# 1      ...               2.0             78.0                23948.0
# 2      ...               2.0             82.0                10752.0
# 3      ...              23.0             38.0                12607.0
# 4      ...              24.0             50.0                25213.0
# ...    ...               ...              ...                    ...
# 14995  ...               1.0              8.0                 6936.0
# 14996  ...               4.0             20.0               202639.0
# 14997  ...              43.0              5.0                44421.0
# 14998  ...               3.0             25.0                22409.0
# 14999  ...               2.0             82.0                 8084.0
#
#        debit_amount_jun  credit_amount_jun  credit_count_jun  debit_count_jun  \
# 0              30051.32           12761.00               2.0             65.0
# 1              42119.05           76206.00              21.0             63.0
# 2              58373.25           75283.00               7.0              1.0
# 3              69851.51           68708.00              21.0             83.0
# 4              10071.00           80140.00               8.0             32.0
# ...                 ...                ...               ...              ...
# 14995         487751.19           42625.50              14.0              8.0
# 14996           8666.01           34987.55              11.0             18.0
# 14997          97896.48          261432.00               4.0             73.0
# 14998          22693.92           33025.29               3.0             80.0
# 14999          41328.96           78574.00              47.0             50.0
#
#        max_credit_amount_jun  emi_active   cc_cons
# 0                   50836.00     1674.09   20014.0
# 1                   23226.00    13043.34   10173.0
# 2                   27036.00    25375.27   16095.0
# 3                   43037.00     3544.33    7707.0
# 4                   32044.00    12780.44   96408.0
# ...                      ...         ...       ...
# 14995               82851.00    78966.76    4263.0
# 14996              118110.47     4762.10   11019.0
# 14997               49545.00     2877.33  404227.0
# 14998               16130.00    13006.84   28813.0
# 14999               22849.00     1588.60   16252.0
#
# [15000 rows x 38 columns]

# %%
df2=df2.drop(columns=df2[['personal_loan_active','vehicle_loan_active','personal_loan_closed','vehicle_loan_closed']])

# %%
test_data.columns
# Out:
# Index(['ID', 'account_type', 'gender', 'age', 'region_code', 'cc_cons_apr',
#        'dc_cons_apr', 'cc_cons_may', 'dc_cons_may', 'cc_cons_jun',
#        'dc_cons_jun', 'cc_count_apr', 'cc_count_may', 'cc_count_jun',
#        'dc_count_apr', 'dc_count_may', 'dc_count_jun', 'card_lim',
#        'personal_loan_active', 'vehicle_loan_active', 'personal_loan_closed',
#        'vehicle_loan_closed', 'investment_1', 'investment_2', 'investment_3',
#        'investment_4', 'debit_amount_apr', 'credit_amount_apr',
#        'debit_count_apr', 'credit_count_apr', 'max_credit_amount_apr',
#        'debit_amount_may', 'credit_amount_may', 'credit_count_may',
#        'debit_count_may', 'max_credit_amount_may', 'debit_amount_jun',
#        'credit_amount_jun', 'credit_count_jun', 'debit_count_jun',
#        'max_credit_amount_jun', 'loan_enq', 'emi_active'],
#       dtype='object')

# %%
df_max=pd.DataFrame(df1.max())

# %%
df_max=df_max.reset_index()

# %%
df_max.rename(columns = {'index':'Maximum amount of each category',0:'Maximum_amount'}, inplace = True)

# %%
df_max
# Out:
#   Maximum amount of each category Maximum_amount
# 0                    account_type         saving
# 1                          gender              M
# 2                        loan_enq              Y

# %%
q1=df2.quantile(0.25)
q3=df2.quantile(0.75)
iqr=q3-q1
ll=q1-(3*iqr)
ul=q3+(3*iqr)

# %%
(df2['investment_4']<0).sum()
# Out:
# 3225

# %%
num=list()
for a in df2.columns:
    if a in ll.index:
        num.append(a)

# %%
df2=df2[num]

# %%
df = df2[~((df2 < (q1 - 1.5 * iqr)) |(df2 > (q3 + 1.5 * iqr))).any(axis=1)]

# %%
df
# Out:
#        cc_cons_apr  dc_cons_apr  cc_cons_may  dc_cons_may  cc_cons_jun  \
# 1         18941.62       966.00     20672.00       287.00     4217.000
# 15         4375.13      1035.00     14183.42     12489.00    10521.500
# 75         2080.00       240.00      1052.30      2047.00     1069.000
# 126        2606.15      7222.00      6406.00     10061.34     2484.000
# 164       23657.84      6463.95       283.65      9272.15     6850.500
# ...            ...          ...          ...          ...          ...
# 14974      6174.68      3822.00      9866.14      5393.67     5663.225
# 14981     27105.74       933.20      4717.00      3876.00     9883.960
# 14983      1891.58       255.00      3001.95       287.00    13459.965
# 14989      3844.50      7684.00      4077.09      3337.94     5848.000
# 14992     14181.00     15759.00     27766.51       498.00    11139.545
#
#        dc_cons_jun  cc_count_apr  cc_count_may  cc_count_jun  dc_count_apr  \
# 1           885.00           1.0           7.0          13.0           3.0
# 15         5124.00          24.0          27.0          79.0           8.0
# 75         1023.00          43.0          85.0          48.0          20.0
# 126        5246.00           8.0          23.0          47.0          48.0
# 164       15647.48          60.0           2.0          47.0           8.0
# ...            ...           ...           ...           ...           ...
# 14974      3327.00          12.0          50.0           4.0           8.0
# 14981      1204.12          25.0          18.0          47.0           7.0
# 14983      3176.00         100.0          77.0          38.0          18.0
# 14989      1981.00           8.0          10.0          74.0           3.0
# 14992      1048.66           5.0           5.0          84.0          57.0
#
#        ...  credit_count_may  debit_count_may  max_credit_amount_may  \
# 1      ...               2.0             78.0               23948.00
# 15     ...               2.0             12.0               19669.00
# 75     ...              10.0              9.0               23349.00
# 126    ...               9.0              6.0               35241.00
# 164    ...               2.0             78.0               19821.00
# ...    ...               ...              ...                    ...
# 14974  ...               1.0             13.0               27034.09
# 14981  ...               2.0              4.0               24320.00
# 14983  ...               1.0             20.0               16000.00
# 14989  ...               2.0             35.0               16187.00
# 14992  ...               3.0             11.0               31128.00
#
#        debit_amount_jun  credit_amount_jun  credit_count_jun  debit_count_jun  \
# 1              42119.05           76206.00              21.0             63.0
# 15             39971.35             461.79               3.0             83.0
# 75             15350.00           36734.26               5.0             21.0
# 126             8892.20           23907.00              13.0            124.0
# 164            67181.60             365.76               4.0             12.0
# ...                 ...                ...               ...              ...
# 14974          78592.91          102657.50              40.0             58.0
# 14981          68356.73          140120.00               6.0             83.0
# 14983          62746.00           51494.00               4.0            104.0
# 14989            793.00           42396.00              41.0             36.0
# 14992          41973.58           64567.63              19.0             58.0
#
#        max_credit_amount_jun  emi_active  cc_cons
# 1                   23226.00    13043.34  10173.0
# 15                  10040.39      288.38  10069.0
# 75                  24821.00     2183.10  27930.0
# 126                 15656.00     4625.45  14474.0
# 164                 18600.00    20586.84    966.0
# ...                      ...         ...      ...
# 14974               30107.00     2307.10   7705.0
# 14981               35485.00     2909.80   3336.0
# 14983               17003.00     1360.05  10064.0
# 14989               13070.00     2646.18  12310.0
# 14992               25360.00     6284.72  11780.0
#
# [985 rows x 34 columns]

# %%
df_train = df_train.dropna(how ='all') 
df_train.drop(df[df.columns].index, inplace = True)

# %%
df1=df_train.loc[:,df_train.dtypes==np.object]
df2=df_train.loc[:,df_train.dtypes==np.number]

# %%
import matplotlib.pyplot as plt
for i in df2.columns:
    plt.scatter(x=df2['cc_cons'],y=df2[i])
    plt.xlabel(i)
    plt.show()

# %%
df2['investment_4']=df2['investment_4'].add(12179)
#cr_log=df2.applymap(lambda x: np.log(x+1))
#df2['investment_4'].describe()
#


cr_log=df2.applymap(lambda x: np.log(x+1))
# Out:
# C:\Users\DAZZABHI\Miniconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
(df2['investment_4']<0).sum()
# Out:
# 0

# %%
df2['investment_4'].describe()
# Out:
# count    14015.000000
# mean     15778.938082
# std       7489.245947
# min          0.000000
# 25%      12179.000000
# 50%      14530.000000
# 75%      19064.000000
# max      47525.000000
# Name: investment_4, dtype: float64

# %%
#cr_log
test_data_numeric
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-533-461edceb796d> in <module>
#       1 #cr_log
# ----> 2 test_data_numeric
#
# NameError: name 'test_data_numeric' is not defined

# %%
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
mm_scaler = StandardScaler()
cr_log[cr_log.columns] =mm_scaler.fit_transform(cr_log[cr_log.columns])
cr_log

# %%
import seaborn as sns
fig,ax1=plt.subplots(figsize=(10,10))
ax1=sns.distplot(df2['investment_4'], label = 'Before_Scaling', ax = ax1, kde =True,bins=40,color ='red')
#ax2=sns.distplot(df_normalized['cc_cons'], label = 'After_Scaling', ax = ax2, kde =True,bins=40,color ='red')

# %%
sns.distplot(cr_log['investment_4'], label = 'After_Scaling', kde =True,bins=40,color ='red')

# %%
test_data = pd.read_csv('Test.csv')

# %%
test_data

# %%
corr=df2.corr()
#sns.heatmap(data=corr,annot=True)
#df2=df2.drop(columns=df2[['personal_loan_active','vehicle_loan_active','personal_loan_closed','vehicle_loan_closed']])

# %%
f, ax5 = plt.subplots(figsize=(30, 20))
sns.heatmap(corr, annot=True, linewidths=.5, ax=ax5,)

# %%
S=pd.get_dummies(df1[['account_type', 'gender', 'loan_enq']]).astype('float64')
S
# Out:
#        account_type_current  account_type_saving  gender_F  gender_M  \
# 0                       1.0                  0.0       0.0       1.0
# 2                       1.0                  0.0       0.0       1.0
# 3                       1.0                  0.0       1.0       0.0
# 4                       1.0                  0.0       0.0       1.0
# 5                       1.0                  0.0       0.0       1.0
# ...                     ...                  ...       ...       ...
# 14995                   1.0                  0.0       1.0       0.0
# 14996                   1.0                  0.0       0.0       1.0
# 14997                   1.0                  0.0       0.0       1.0
# 14998                   1.0                  0.0       0.0       1.0
# 14999                   1.0                  0.0       0.0       1.0
#
#        loan_enq_Y
# 0             1.0
# 2             1.0
# 3             1.0
# 4             1.0
# 5             1.0
# ...           ...
# 14995         1.0
# 14996         1.0
# 14997         1.0
# 14998         1.0
# 14999         1.0
#
# [14015 rows x 5 columns]

# %%
df3=pd.concat([S,cr_log],axis=1).astype('float64')
df3
# Out:
#        account_type_current  account_type_saving  gender_F  gender_M  \
# 0                       1.0                  0.0       0.0       1.0
# 2                       1.0                  0.0       0.0       1.0
# 3                       1.0                  0.0       1.0       0.0
# 4                       1.0                  0.0       0.0       1.0
# 5                       1.0                  0.0       0.0       1.0
# ...                     ...                  ...       ...       ...
# 14995                   1.0                  0.0       1.0       0.0
# 14996                   1.0                  0.0       0.0       1.0
# 14997                   1.0                  0.0       0.0       1.0
# 14998                   1.0                  0.0       0.0       1.0
# 14999                   1.0                  0.0       0.0       1.0
#
#        loan_enq_Y  cc_cons_apr  dc_cons_apr  cc_cons_may  dc_cons_may  \
# 0             1.0    10.122382     5.937536     9.238831    10.297723
# 2             1.0     8.644684     7.910224     7.583502     8.277440
# 3             1.0    10.325170     7.120444     9.442315     9.120322
# 4             1.0     8.914949     8.840296     8.381373     7.570443
# 5             1.0     7.753289     7.376846     9.902525     6.953541
# ...           ...          ...          ...          ...          ...
# 14995         1.0     9.253856     7.106483     8.889204     8.262043
# 14996         1.0    10.305324     8.749732     9.681999     8.937350
# 14997         1.0     8.330859     6.856188     9.871029     6.204558
# 14998         1.0    11.657675     8.880732    10.699691    10.457896
# 14999         1.0     8.906078     5.729450     8.675988     8.810370
#
#        cc_cons_jun  ...  credit_count_may  debit_count_may  \
# 0         9.698454  ...          1.098612         3.713572
# 2        10.084026  ...          1.098612         4.418841
# 3         9.771213  ...          3.178054         3.663562
# 4         7.660114  ...          3.218876         3.931826
# 5         9.366254  ...          3.784190         1.098612
# ...            ...  ...               ...              ...
# 14995     8.799963  ...          0.693147         2.197225
# 14996     7.702592  ...          1.609438         3.044522
# 14997    10.700204  ...          3.784190         1.791759
# 14998     9.936922  ...          1.386294         3.258097
# 14999    10.410686  ...          1.098612         4.418841
#
#        max_credit_amount_may  debit_amount_jun  credit_amount_jun  \
# 0                  10.109037         10.310695           9.454227
# 2                   9.282940         10.974630          11.229023
# 3                   9.442087         11.154141          11.137635
# 4                  10.135155          9.217515          11.291543
# 5                   9.973060         10.864631          12.205705
# ...                      ...               ...                ...
# 14995               8.844625         13.097563          10.660231
# 14996              12.219186          9.067279          10.462776
# 14997              10.701490         11.491676          12.473933
# 14998              10.017263         10.029896          10.405059
# 14999               8.997766         10.629343          11.271809
#
#        credit_count_jun  debit_count_jun  max_credit_amount_jun  emi_active  \
# 0              1.098612         4.189655              10.836380    7.423622
# 2              2.079442         0.693147              10.204962   10.141570
# 3              3.091042         4.430817              10.669839    8.173387
# 4              2.197225         3.496508              10.374896    9.455749
# 5              1.098612         3.583519               9.757594    8.522678
# ...                 ...              ...                    ...         ...
# 14995          2.708050         2.197225              11.324811   11.276795
# 14996          2.484907         2.944439              11.679384    8.468654
# 14997          1.609438         4.304065              10.810657    7.964966
# 14998          1.386294         4.394449               9.688498    9.473308
# 14999          3.871201         3.931826              10.036706    7.371238
#
#          cc_cons
# 0       9.904237
# 2       9.686326
# 3       8.950014
# 4      11.476355
# 5      11.777318
# ...          ...
# 14995   8.357963
# 14996   9.307467
# 14997  12.909734
# 14998  10.268617
# 14999   9.696033
#
# [14015 rows x 43 columns]

# %%
X=df3.iloc[:,df3.columns!='cc_cons']
y=df3['cc_cons']
X
# Out:
#        account_type_current  account_type_saving  gender_F  gender_M  \
# 0                       1.0                  0.0       0.0       1.0
# 2                       1.0                  0.0       0.0       1.0
# 3                       1.0                  0.0       1.0       0.0
# 4                       1.0                  0.0       0.0       1.0
# 5                       1.0                  0.0       0.0       1.0
# ...                     ...                  ...       ...       ...
# 14995                   1.0                  0.0       1.0       0.0
# 14996                   1.0                  0.0       0.0       1.0
# 14997                   1.0                  0.0       0.0       1.0
# 14998                   1.0                  0.0       0.0       1.0
# 14999                   1.0                  0.0       0.0       1.0
#
#        loan_enq_Y  cc_cons_apr  dc_cons_apr  cc_cons_may  dc_cons_may  \
# 0             1.0    10.122382     5.937536     9.238831    10.297723
# 2             1.0     8.644684     7.910224     7.583502     8.277440
# 3             1.0    10.325170     7.120444     9.442315     9.120322
# 4             1.0     8.914949     8.840296     8.381373     7.570443
# 5             1.0     7.753289     7.376846     9.902525     6.953541
# ...           ...          ...          ...          ...          ...
# 14995         1.0     9.253856     7.106483     8.889204     8.262043
# 14996         1.0    10.305324     8.749732     9.681999     8.937350
# 14997         1.0     8.330859     6.856188     9.871029     6.204558
# 14998         1.0    11.657675     8.880732    10.699691    10.457896
# 14999         1.0     8.906078     5.729450     8.675988     8.810370
#
#        cc_cons_jun  ...  credit_amount_may  credit_count_may  debit_count_may  \
# 0         9.698454  ...          12.164094          1.098612         3.713572
# 2        10.084026  ...          11.170139          1.098612         4.418841
# 3         9.771213  ...          11.051443          3.178054         3.663562
# 4         7.660114  ...          10.318474          3.218876         3.931826
# 5         9.366254  ...           9.882519          3.784190         1.098612
# ...            ...  ...                ...               ...              ...
# 14995     8.799963  ...          10.072935          0.693147         2.197225
# 14996     7.702592  ...          10.820258          1.609438         3.044522
# 14997    10.700204  ...          10.469937          3.784190         1.791759
# 14998     9.936922  ...          11.316838          1.386294         3.258097
# 14999    10.410686  ...          10.323250          1.098612         4.418841
#
#        max_credit_amount_may  debit_amount_jun  credit_amount_jun  \
# 0                  10.109037         10.310695           9.454227
# 2                   9.282940         10.974630          11.229023
# 3                   9.442087         11.154141          11.137635
# 4                  10.135155          9.217515          11.291543
# 5                   9.973060         10.864631          12.205705
# ...                      ...               ...                ...
# 14995               8.844625         13.097563          10.660231
# 14996              12.219186          9.067279          10.462776
# 14997              10.701490         11.491676          12.473933
# 14998              10.017263         10.029896          10.405059
# 14999               8.997766         10.629343          11.271809
#
#        credit_count_jun  debit_count_jun  max_credit_amount_jun  emi_active
# 0              1.098612         4.189655              10.836380    7.423622
# 2              2.079442         0.693147              10.204962   10.141570
# 3              3.091042         4.430817              10.669839    8.173387
# 4              2.197225         3.496508              10.374896    9.455749
# 5              1.098612         3.583519               9.757594    8.522678
# ...                 ...              ...                    ...         ...
# 14995          2.708050         2.197225              11.324811   11.276795
# 14996          2.484907         2.944439              11.679384    8.468654
# 14997          1.609438         4.304065              10.810657    7.964966
# 14998          1.386294         4.394449               9.688498    9.473308
# 14999          3.871201         3.931826              10.036706    7.371238
#
# [14015 rows x 42 columns]

# %%
#X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=43)
lasso=Lasso(alpha=0.01)
lasso.fit(X,y)
y_pred=lasso.predict(cr_log1)
#print(np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-548-85e53c431bff> in <module>
#       2 lasso=Lasso(alpha=0.01)
#       3 lasso.fit(X,y)
# ----> 4 y_pred=lasso.predict(cr_log1)
#       5 #print(np.sqrt(mean_squared_error(y_test,y_pred)))
#
# ~\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_base.py in predict(self, X)
#     223             Returns predicted values.
#     224         """
# --> 225         return self._decision_function(X)
#     226
#     227     _preprocess_data = staticmethod(_preprocess_data)
#
# ~\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_coordinate_descent.py in _decision_function(self, X)
#     792                                    dense_output=True) + self.intercept_
#     793         else:
# --> 794             return super()._decision_function(X)
#     795
#     796
#
# ~\AppData\Roaming\Python\Python37\site-packages\sklearn\linear_model\_base.py in _decision_function(self, X)
#     207         X = check_array(X, accept_sparse=['csr', 'csc', 'coo'])
#     208         return safe_sparse_dot(X, self.coef_.T,
# --> 209                                dense_output=True) + self.intercept_
#     210
#     211     def predict(self, X):
#
# ~\AppData\Roaming\Python\Python37\site-packages\sklearn\utils\extmath.py in safe_sparse_dot(a, b, dense_output)
#     149             ret = np.dot(a, b)
#     150     else:
# --> 151         ret = a @ b
#     152
#     153     if (sparse.issparse(a) and sparse.issparse(b)
#
# ValueError: matmul: Input operand 1 has a mismatch in its core dimension 0, with gufunc signature (n?,k),(k,m?)->(n?,m?) (size 42 is different from 33)

# %%
test_data=pd.read_csv('test.csv')

# %%
test_data.drop(['loan_enq','region_code','ID','age','personal_loan_active','vehicle_loan_active','personal_loan_closed','vehicle_loan_closed'],axis=1)
# Out:
#      account_type gender  cc_cons_apr  dc_cons_apr  cc_cons_may  dc_cons_may  \
# 0         current      M     2795.450      1290.00      6141.05       676.50
# 1         current      M    29405.130      1640.00      1670.00      2463.92
# 2         current      M     5985.200      6189.00      2696.09       766.00
# 3         current      M     2105.930     18225.00     34763.56       167.00
# 4         current      M     3269.000      3532.00      3158.40      2699.77
# ...           ...    ...          ...          ...          ...          ...
# 4995      current      M     4641.500      5979.58      6008.61      4410.00
# 4996      current      M     4994.450      2805.37     23214.00      5870.00
# 4997      current      M     3262.145      2871.00      7335.25     11774.04
# 4998      current      M    12824.010      4866.00     12242.48       284.00
# 4999      current      M    26218.000      6615.00      2832.00      4642.00
#
#       cc_cons_jun  dc_cons_jun  cc_count_apr  cc_count_may  ...  \
# 0         9146.10     15479.00           4.0          10.0  ...
# 1        10947.50       956.00           3.0          10.0  ...
# 2          716.00      4133.22           7.0          30.0  ...
# 3         4260.27     20185.00           1.0          99.0  ...
# 4         3373.48      5120.00           2.0          10.0  ...
# ...           ...          ...           ...           ...  ...
# 4995     41743.00      1884.00          26.0           1.0  ...
# 4996      1041.00      1008.73          37.0          56.0  ...
# 4997      4130.00      1413.00          12.0          77.0  ...
# 4998     15132.77     37911.00          67.0           1.0  ...
# 4999      1314.64     11355.00           7.0           1.0  ...
#
#       credit_amount_may  credit_count_may  debit_count_may  \
# 0              41755.00              24.0             20.0
# 1             130299.00              43.0             40.0
# 2              40422.00              42.0             35.0
# 3              48148.00               3.0              5.0
# 4              25926.00              70.0             75.0
# ...                 ...               ...              ...
# 4995           45461.00              35.0             11.0
# 4996           85422.00               5.0              8.0
# 4997           68985.86              10.0            108.0
# 4998           13558.00              11.0             12.0
# 4999          142612.61               7.0             13.0
#
#       max_credit_amount_may  debit_amount_jun  credit_amount_jun  \
# 0                    9750.0          30527.88           31271.00
# 1                   16967.0          14342.83           16582.00
# 2                   36398.0          32503.16           33539.54
# 3                   97825.0          93572.42          109429.75
# 4                   27936.0          19011.50           41401.00
# ...                     ...               ...                ...
# 4995                32944.0         105488.53          125470.83
# 4996                 8850.0          77112.66           86559.00
# 4997                35819.0          57192.48           80627.00
# 4998                39083.0          82039.00           24332.00
# 4999                22831.0          60035.50           76669.00
#
#       credit_count_jun  debit_count_jun  max_credit_amount_jun  emi_active
# 0                  3.0             12.0               25945.92     1170.49
# 1                  6.0             39.0               12214.00    16447.45
# 2                  5.0              9.0               13215.00     2622.28
# 3                 21.0              0.0               72317.00      340.79
# 4                  6.0             35.0               42344.00     2812.20
# ...                ...              ...                    ...         ...
# 4995              21.0             50.0               58037.00     7870.88
# 4996              62.0             38.0               24110.00     3668.30
# 4997               2.0             18.0                1769.00     5450.34
# 4998             117.0             64.0               37255.00       59.29
# 4999               9.0             64.0               96213.00      793.41
#
# [5000 rows x 35 columns]

# %%
df_test_categorical=df_train.loc[:,df_train.dtypes==np.object]
df_test_numerical=df_train.loc[:,df_train.dtypes==np.number]

# %%
#df_test_numerical['investment_4'].describe()
df_test_numerical['investment_4']=df_test_numerical['investment_4'].add(12179)
cr_log1=df_test_numerical.applymap(lambda x: np.log(x+1))
# Out:
# C:\Users\DAZZABHI\Miniconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
mm_scaler1 = StandardScaler()
cr_log1[cr_log1.columns] =mm_scaler1.fit_transform(cr_log1[cr_log1.columns])
cr_log1
# Out:
#        cc_cons_apr  dc_cons_apr  cc_cons_may  dc_cons_may  cc_cons_jun  \
# 0         0.806590    -1.764070     0.171898     1.673967     0.788781
# 2        -0.455286    -0.253442    -1.196486     0.060717     1.115626
# 3         0.979760    -0.858232     0.340110     0.733781     0.850458
# 4        -0.224494     0.458782    -0.536922    -0.503838    -0.939096
# 5        -1.216489    -0.661887     0.720544    -0.996451     0.507179
# ...            ...          ...          ...          ...          ...
# 14995     0.064915    -0.868923    -0.117122     0.048422     0.027141
# 14996     0.962812     0.389430     0.538245     0.587673    -0.903088
# 14997    -0.723275    -1.060592     0.694508    -1.594534     1.637953
# 14998     2.117647     0.489746     1.379524     1.801869     0.990928
# 14999    -0.232069    -1.923416    -0.293377     0.486276     1.392532
#
#        dc_cons_jun  cc_count_apr  cc_count_may  cc_count_jun  dc_count_apr  \
# 0         0.982289     -1.209225      0.286431     -0.758847      1.362834
# 2         0.361204      0.803800      0.464971      1.241390     -0.524701
# 3         1.121032      0.957307     -2.029228      0.612835     -1.282476
# 4         0.579235      1.130101      0.798342      1.048337      1.458363
# 5        -1.286759     -0.574117     -0.795817      0.758164      0.838743
# ...            ...           ...           ...           ...           ...
# 14995     0.885916     -0.993587      0.566764     -1.663448      1.292408
# 14996    -1.058017     -1.513149      0.517322     -1.463907     -0.136007
# 14997    -0.462937      1.010871      0.181637      0.787485      0.806307
# 14998    -0.915462     -0.474026      1.677927      0.500911     -0.709241
# 14999    -1.966021      0.491309      1.159091     -0.758847      0.984205
#
#        ...  credit_count_may  debit_count_may  max_credit_amount_may  \
# 0      ...         -0.722459         0.436523              -0.197173
# 2      ...         -0.722459         1.106652              -0.882366
# 3      ...          1.119897         0.389004              -0.750364
# 4      ...          1.156065         0.643902              -0.175510
# 5      ...          1.656924        -2.048150              -0.309957
# ...    ...               ...              ...                    ...
# 14995  ...         -1.081695        -1.004274              -1.245920
# 14996  ...         -0.269874        -0.199192               1.553056
# 14997  ...          1.656924        -1.389538               0.294227
# 14998  ...         -0.467576         0.003741              -0.273294
# 14999  ...         -0.722459         1.106652              -1.118899
#
#        debit_amount_jun  credit_amount_jun  credit_count_jun  debit_count_jun  \
# 0             -0.343088          -0.881881         -1.212141         0.730640
# 2              0.249084           0.451576         -0.315305        -2.395342
# 3              0.409192           0.382914          0.609668         0.946246
# 4             -1.318110           0.498550         -0.207608         0.110946
# 5              0.150974           1.185387         -1.212141         0.188736
# ...                 ...                ...               ...              ...
# 14995          2.142554           0.024226          0.259473        -1.050652
# 14996         -1.452107          -0.124128          0.055438        -0.382620
# 14997          0.710243           1.386915         -0.745060         0.832926
# 14998         -0.593536          -0.167493         -0.949095         0.913732
# 14999         -0.058882           0.483723          1.323018         0.500133
#
#        max_credit_amount_jun  emi_active   cc_cons
# 0                   0.447501   -0.453558  0.129363
# 2                  -0.029727    1.184041 -0.004017
# 3                   0.321628   -0.001815 -0.454701
# 4                   0.098710    0.770826  1.091628
# 5                  -0.367848    0.208638  1.275843
# ...                      ...         ...       ...
# 14995               0.816658    1.868029 -0.817085
# 14996               1.084645    0.176088 -0.235910
# 14997               0.428059   -0.127391  1.968975
# 14998              -0.420071    0.781405  0.352393
# 14999              -0.156894   -0.485120  0.001924
#
# [14015 rows x 38 columns]

# %%
S1=pd.get_dummies(df_test_categorical[['account_type', 'gender']]).astype('float64')
S1
# Out:
#        account_type_current  account_type_saving  gender_F  gender_M
# 0                       1.0                  0.0       0.0       1.0
# 2                       1.0                  0.0       0.0       1.0
# 3                       1.0                  0.0       1.0       0.0
# 4                       1.0                  0.0       0.0       1.0
# 5                       1.0                  0.0       0.0       1.0
# ...                     ...                  ...       ...       ...
# 14995                   1.0                  0.0       1.0       0.0
# 14996                   1.0                  0.0       0.0       1.0
# 14997                   1.0                  0.0       0.0       1.0
# 14998                   1.0                  0.0       0.0       1.0
# 14999                   1.0                  0.0       0.0       1.0
#
# [14015 rows x 4 columns]

# %%
df_test=pd.concat([S1,cr_log1],axis=1).astype('float64')
df_test
# Out:
#        account_type_current  account_type_saving  gender_F  gender_M  \
# 0                       1.0                  0.0       0.0       1.0
# 2                       1.0                  0.0       0.0       1.0
# 3                       1.0                  0.0       1.0       0.0
# 4                       1.0                  0.0       0.0       1.0
# 5                       1.0                  0.0       0.0       1.0
# ...                     ...                  ...       ...       ...
# 14995                   1.0                  0.0       1.0       0.0
# 14996                   1.0                  0.0       0.0       1.0
# 14997                   1.0                  0.0       0.0       1.0
# 14998                   1.0                  0.0       0.0       1.0
# 14999                   1.0                  0.0       0.0       1.0
#
#        cc_cons_apr  dc_cons_apr  cc_cons_may  dc_cons_may  cc_cons_jun  \
# 0         0.806590    -1.764070     0.171898     1.673967     0.788781
# 2        -0.455286    -0.253442    -1.196486     0.060717     1.115626
# 3         0.979760    -0.858232     0.340110     0.733781     0.850458
# 4        -0.224494     0.458782    -0.536922    -0.503838    -0.939096
# 5        -1.216489    -0.661887     0.720544    -0.996451     0.507179
# ...            ...          ...          ...          ...          ...
# 14995     0.064915    -0.868923    -0.117122     0.048422     0.027141
# 14996     0.962812     0.389430     0.538245     0.587673    -0.903088
# 14997    -0.723275    -1.060592     0.694508    -1.594534     1.637953
# 14998     2.117647     0.489746     1.379524     1.801869     0.990928
# 14999    -0.232069    -1.923416    -0.293377     0.486276     1.392532
#
#        dc_cons_jun  ...  credit_count_may  debit_count_may  \
# 0         0.982289  ...         -0.722459         0.436523
# 2         0.361204  ...         -0.722459         1.106652
# 3         1.121032  ...          1.119897         0.389004
# 4         0.579235  ...          1.156065         0.643902
# 5        -1.286759  ...          1.656924        -2.048150
# ...            ...  ...               ...              ...
# 14995     0.885916  ...         -1.081695        -1.004274
# 14996    -1.058017  ...         -0.269874        -0.199192
# 14997    -0.462937  ...          1.656924        -1.389538
# 14998    -0.915462  ...         -0.467576         0.003741
# 14999    -1.966021  ...         -0.722459         1.106652
#
#        max_credit_amount_may  debit_amount_jun  credit_amount_jun  \
# 0                  -0.197173         -0.343088          -0.881881
# 2                  -0.882366          0.249084           0.451576
# 3                  -0.750364          0.409192           0.382914
# 4                  -0.175510         -1.318110           0.498550
# 5                  -0.309957          0.150974           1.185387
# ...                      ...               ...                ...
# 14995              -1.245920          2.142554           0.024226
# 14996               1.553056         -1.452107          -0.124128
# 14997               0.294227          0.710243           1.386915
# 14998              -0.273294         -0.593536          -0.167493
# 14999              -1.118899         -0.058882           0.483723
#
#        credit_count_jun  debit_count_jun  max_credit_amount_jun  emi_active  \
# 0             -1.212141         0.730640               0.447501   -0.453558
# 2             -0.315305        -2.395342              -0.029727    1.184041
# 3              0.609668         0.946246               0.321628   -0.001815
# 4             -0.207608         0.110946               0.098710    0.770826
# 5             -1.212141         0.188736              -0.367848    0.208638
# ...                 ...              ...                    ...         ...
# 14995          0.259473        -1.050652               0.816658    1.868029
# 14996          0.055438        -0.382620               1.084645    0.176088
# 14997         -0.745060         0.832926               0.428059   -0.127391
# 14998         -0.949095         0.913732              -0.420071    0.781405
# 14999          1.323018         0.500133              -0.156894   -0.485120
#
#         cc_cons
# 0      0.129363
# 2     -0.004017
# 3     -0.454701
# 4      1.091628
# 5      1.275843
# ...         ...
# 14995 -0.817085
# 14996 -0.235910
# 14997  1.968975
# 14998  0.352393
# 14999  0.001924
#
# [14015 rows x 42 columns]

# %%
lasso=Lasso(alpha=0.01)
lasso.fit(X,y)
y_pre=lasso.predict(df_test)
#print(np.sqrt(mean_squared_error(y_test,y_pred)))

# %%
test_data
# Out:
#          ID account_type gender  age  region_code  cc_cons_apr  dc_cons_apr  \
# 0     17591      current      M   37          575     2795.450      1290.00
# 1     13541      current      M   33          394    29405.130      1640.00
# 2     13431      current      M   53          324     5985.200      6189.00
# 3      8687      current      M   33          370     2105.930     18225.00
# 4     14727      current      M   62          505     3269.000      3532.00
# ...     ...          ...    ...  ...          ...          ...          ...
# 4995  12512      current      M   35          523     4641.500      5979.58
# 4996  14224      current      M   53          723     4994.450      2805.37
# 4997  18740      current      M   62          863     3262.145      2871.00
# 4998  18134      current      M   34          882    12824.010      4866.00
# 4999  12413      current      M   27          447    26218.000      6615.00
#
#       cc_cons_may  dc_cons_may  cc_cons_jun  ...  credit_count_may  \
# 0         6141.05       676.50      9146.10  ...              24.0
# 1         1670.00      2463.92     10947.50  ...              43.0
# 2         2696.09       766.00       716.00  ...              42.0
# 3        34763.56       167.00      4260.27  ...               3.0
# 4         3158.40      2699.77      3373.48  ...              70.0
# ...           ...          ...          ...  ...               ...
# 4995      6008.61      4410.00     41743.00  ...              35.0
# 4996     23214.00      5870.00      1041.00  ...               5.0
# 4997      7335.25     11774.04      4130.00  ...              10.0
# 4998     12242.48       284.00     15132.77  ...              11.0
# 4999      2832.00      4642.00      1314.64  ...               7.0
#
#       debit_count_may  max_credit_amount_may  debit_amount_jun  \
# 0                20.0                 9750.0          30527.88
# 1                40.0                16967.0          14342.83
# 2                35.0                36398.0          32503.16
# 3                 5.0                97825.0          93572.42
# 4                75.0                27936.0          19011.50
# ...               ...                    ...               ...
# 4995             11.0                32944.0         105488.53
# 4996              8.0                 8850.0          77112.66
# 4997            108.0                35819.0          57192.48
# 4998             12.0                39083.0          82039.00
# 4999             13.0                22831.0          60035.50
#
#       credit_amount_jun  credit_count_jun  debit_count_jun  \
# 0              31271.00               3.0             12.0
# 1              16582.00               6.0             39.0
# 2              33539.54               5.0              9.0
# 3             109429.75              21.0              0.0
# 4              41401.00               6.0             35.0
# ...                 ...               ...              ...
# 4995          125470.83              21.0             50.0
# 4996           86559.00              62.0             38.0
# 4997           80627.00               2.0             18.0
# 4998           24332.00             117.0             64.0
# 4999           76669.00               9.0             64.0
#
#       max_credit_amount_jun  loan_enq  emi_active
# 0                  25945.92         Y     1170.49
# 1                  12214.00         Y    16447.45
# 2                  13215.00         Y     2622.28
# 3                  72317.00         Y      340.79
# 4                  42344.00         Y     2812.20
# ...                     ...       ...         ...
# 4995               58037.00         Y     7870.88
# 4996               24110.00         Y     3668.30
# 4997                1769.00         Y     5450.34
# 4998               37255.00         Y       59.29
# 4999               96213.00         Y      793.41
#
# [5000 rows x 43 columns]

# %%
df_test_categorical=test_data.loc[:,test_data.dtypes==np.object]
df_test_categorical
# Out:
#      account_type gender loan_enq
# 0         current      M        Y
# 1         current      M        Y
# 2         current      M        Y
# 3         current      M        Y
# 4         current      M        Y
# ...           ...    ...      ...
# 4995      current      M        Y
# 4996      current      M        Y
# 4997      current      M        Y
# 4998      current      M        Y
# 4999      current      M        Y
#
# [5000 rows x 3 columns]

# %%
df_test_numerical=test_data.loc[:,test_data.dtypes==np.number]
df_test_numerical
# Out:
#       cc_cons_apr  dc_cons_apr  cc_cons_may  dc_cons_may  cc_cons_jun  \
# 0        2795.450      1290.00      6141.05       676.50      9146.10
# 1       29405.130      1640.00      1670.00      2463.92     10947.50
# 2        5985.200      6189.00      2696.09       766.00       716.00
# 3        2105.930     18225.00     34763.56       167.00      4260.27
# 4        3269.000      3532.00      3158.40      2699.77      3373.48
# ...           ...          ...          ...          ...          ...
# 4995     4641.500      5979.58      6008.61      4410.00     41743.00
# 4996     4994.450      2805.37     23214.00      5870.00      1041.00
# 4997     3262.145      2871.00      7335.25     11774.04      4130.00
# 4998    12824.010      4866.00     12242.48       284.00     15132.77
# 4999    26218.000      6615.00      2832.00      4642.00      1314.64
#
#       dc_cons_jun  cc_count_apr  cc_count_may  cc_count_jun  dc_count_apr  \
# 0        15479.00           4.0          10.0           4.0          47.0
# 1          956.00           3.0          10.0           4.0          50.0
# 2         4133.22           7.0          30.0           5.0          24.0
# 3        20185.00           1.0          99.0          71.0           5.0
# 4         5120.00           2.0          10.0          47.0           5.0
# ...           ...           ...           ...           ...           ...
# 4995      1884.00          26.0           1.0           4.0           1.0
# 4996      1008.73          37.0          56.0          50.0          18.0
# 4997      1413.00          12.0          77.0           1.0           1.0
# 4998     37911.00          67.0           1.0           4.0           1.0
# 4999     11355.00           7.0           1.0          84.0           3.0
#
#       ...  credit_amount_may  credit_count_may  debit_count_may  \
# 0     ...           41755.00              24.0             20.0
# 1     ...          130299.00              43.0             40.0
# 2     ...           40422.00              42.0             35.0
# 3     ...           48148.00               3.0              5.0
# 4     ...           25926.00              70.0             75.0
# ...   ...                ...               ...              ...
# 4995  ...           45461.00              35.0             11.0
# 4996  ...           85422.00               5.0              8.0
# 4997  ...           68985.86              10.0            108.0
# 4998  ...           13558.00              11.0             12.0
# 4999  ...          142612.61               7.0             13.0
#
#       max_credit_amount_may  debit_amount_jun  credit_amount_jun  \
# 0                    9750.0          30527.88           31271.00
# 1                   16967.0          14342.83           16582.00
# 2                   36398.0          32503.16           33539.54
# 3                   97825.0          93572.42          109429.75
# 4                   27936.0          19011.50           41401.00
# ...                     ...               ...                ...
# 4995                32944.0         105488.53          125470.83
# 4996                 8850.0          77112.66           86559.00
# 4997                35819.0          57192.48           80627.00
# 4998                39083.0          82039.00           24332.00
# 4999                22831.0          60035.50           76669.00
#
#       credit_count_jun  debit_count_jun  max_credit_amount_jun  emi_active
# 0                  3.0             12.0               25945.92     1170.49
# 1                  6.0             39.0               12214.00    16447.45
# 2                  5.0              9.0               13215.00     2622.28
# 3                 21.0              0.0               72317.00      340.79
# 4                  6.0             35.0               42344.00     2812.20
# ...                ...              ...                    ...         ...
# 4995              21.0             50.0               58037.00     7870.88
# 4996              62.0             38.0               24110.00     3668.30
# 4997               2.0             18.0                1769.00     5450.34
# 4998             117.0             64.0               37255.00       59.29
# 4999               9.0             64.0               96213.00      793.41
#
# [5000 rows x 37 columns]

# %%
 #for i in df_test_numerical.columns() :
        q1=df_test_numerical[i].quantile(0.25)
        q3=df_test_numerical[i].quantile(0.75)
        iqr=q3-q1
        ll=q1-(3*iqr)
        ul=q3+(3*iqr)
        
        for a in df_test_numerical.columns:
            if a in ll.index:
                num.append(a)
        df_test_numerical=df_test_numerical[num]
        df = df2[~((df2 < (q1 - 1.5 * iqr)) |(df2 > (q3 + 1.5 * iqr))).any(axis=1)]
# Out:
#   File "<ipython-input-382-b3127725f678>", line 1
#     }
#     ^
# SyntaxError: invalid syntax

# %%
def rmsle(y, y_pre):
    sum=0.0
    for x,y in zip(y,y_pred):
        if x<0 or y<0: #check for negative values. 
            continue
        p = np.log(y+1)
        r = np.log(x+1)
        sum = sum + (p - r)**2
    return (sum/len(y_pred))**0.5

# %%
rmsle(y,y_pre)
# Out:
# 0.172566460124724

# %%
y_pre
# Out:
# array([10.28038545, 10.25696494, 10.29090203, ..., 10.25704529,
#        10.24511058, 10.27685886])

# %%
15000-14015
# Out:
# 985

# %%
985/15000
# Out:
# 0.06566666666666666
